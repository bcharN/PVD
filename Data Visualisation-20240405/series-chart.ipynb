# %% [markdown]
# # CHART FROM SERIES
# ---

# %% [markdown]
# ## Creating Chart From Data Series
#
# To create a chart, first you have to import the necessary librares:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Now, you need data to plot a chart. The data below shows the number of people who watched the latest movie in the cinema, from Monday to Friday.

# %%
data = [410,395,515,457,490]
ds = pd.Series(data)
ds
# Out:
# 0    410
# 1    395
# 2    515
# 3    457
# 4    490
# dtype: int64

# %% [markdown]
# To create a plot, use the plot() function:\
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %%
ds.plot()
# Out:
# <Axes: >

# %% [markdown]
# To add labels on the X axis, add an index to the dataset you created.

# %%
weekname = ['Monday','Tuesday','Wednesday','Thursday','Friday']
ds.index = weekname
ds
# Out:
# Monday       410
# Tuesday      395
# Wednesday    515
# Thursday     457
# Friday       490
# dtype: int64

# %%
ds.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Tasks

# %% [markdown]
# On Saturday and Sunday, the movie was watched by 610 and 692 people, respectively. Complete the chart with this data.

# %%
wv = [610,692]
wn = ["Saturday","Sunday"]
data += wv
weekname += wn
weekname
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
ads = pd.Series(data,index=weekname)
ads
# Out:
# Monday       410
# Tuesday      395
# Wednesday    515
# Thursday     457
# Friday       490
# Saturday     610
# Sunday       692
# dtype: int64

# %%
ads.plot(
)
# Out:
# <Axes: >

# %% [markdown]
# ## Adding Chart Title and Axis Description

# %% [markdown]
# Each chart should have a title. To add it, use the plot() function attribute.

# %%
ds.plot(title="People Watched a Movie")
# Out:
# <Axes: title={'center': 'People Watched a Movie'}>

# %% [markdown]
# To add a description of the X-axis of the plot, use the appropriate attribute of the plot() function.

# %%
ds.plot(title="People Watched a Movie", xlabel='Days of Week')
# Out:
# <Axes: title={'center': 'People Watched a Movie'}, xlabel='Days of Week'>

# %% [markdown]
# ### Tasks
#
# Now try to add the correct description of the Y axis.

# %%
ds.plot(title="People Watched a Movie", xlabel='Days of Week',ylabel="Number of Views")
# Out:
# <Axes: title={'center': 'People Watched a Movie'}, xlabel='Days of Week', ylabel='Number of Views'>

# %% [markdown]
# ## Changing Chart Type
#
# By default, a line chart is created. To change the type of chart to a bar, use the kind attribute.

# %%
ds.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# If you would like to create a pie chart, apply the value 'pie' to the kind attribute.

# %%
ds.plot(kind='pie', autopct='%1.0f%%')
# Out:
# <Axes: >

# %% [markdown]
# ### Tasks
#
# Complete the above bar chart by adding its title and axis descriptions.

# %%
ads.plot(kind='bar',title="People Watched a Movie", xlabel='Days of Week',ylabel="Number of Views")
# Out:
# <Axes: title={'center': 'People Watched a Movie'}, xlabel='Days of Week', ylabel='Number of Views'>

# %% [markdown]
# The calorie content of a student's meals is as follows: breakfast 650 calories, lunch 420 calories and dinner 890 calories. Present the data in a bar chart. Add a chart title, axis descriptions, and correct x-axis labels.

# %%
calories = [650,420,890]
labels = ["breakfast","lunch","dinner"]
calories = pd.Series(calories, index=labels)
calories
# Out:
# breakfast    650
# lunch        420
# dinner       890
# dtype: int64

# %%
calories.plot(kind="bar",title="Number of Calories for each meal",xlabel="meal",ylabel="calories")
# Out:
# <Axes: title={'center': 'Number of Calories for each meal'}, xlabel='meal', ylabel='calories'>

# %% [markdown]
# The company's department employs 37 people, 14 of which are women. Create a pie chart showing the percentage of men and women employed in this department.

# %%
com = [14,37-14]
lab = ["women","men"]
company = pd.Series(com,index=lab)
company
# Out:
# women    14
# men      23
# dtype: int64

# %%
company.plot(kind='pie',autopct='%1.0f%%')
# Out:
# <Axes: >

# %% [markdown]
# # grand slam

# %%
columns = [    "Player" ,"Titles"]

data={
    "Novak Djokovic" : 24,
    "Rafael Nadal"   : 22,
    "Roger Federer"  : 20,
    "Pete Sampras"   : 14,
}
gs = pd.Series(data=data)
gs
# Out:
# Novak Djokovic    24
# Rafael Nadal      22
# Roger Federer     20
# Pete Sampras      14
# dtype: int64

# %%
gs.plot(kind='bar',title="Grand Slam",xlabel="Player",ylabel="Score")
# Out:
# <Axes: title={'center': 'Grand Slam'}, xlabel='Player', ylabel='Score'>
