# %%
import pandas as pd

# %%
comp = pd.read_csv('comp_no_of_people.csv')
comp
# Out:
#           Company                Department  #Men  #Women
# 0            Ntag                     Sales    59       8
# 1           Vimbo               Engineering    51      36
# 2   Chatterbridge      Business Development    83      49
# 3        Zoomcast               Engineering    54      64
# 4    Jabbersphere      Business Development    72      54
# 5          Yambee      Business Development    68      40
# 6       Bubblemix               Engineering    70      30
# 7            Layo                Accounting    93      18
# 8          Yambee                     Legal    14      40
# 9         Blogpad  Research and Development    87      49
# 10         Zooveo           Human Resources    23      93
# 11         Twimbo                  Training    55      54
# 12          Skiba                Accounting    14      89
# 13        Trilith                 Marketing    10      23
# 14          Oodoo                  Services    15      58
# ...

# %%
comp.loc[:,'#Men'].sum()
# Out:
# 1029

# %%
comp.loc[:,'#Women'].mean()
# Out:
# 46.75
